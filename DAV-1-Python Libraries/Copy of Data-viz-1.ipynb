# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Settings the warnings to be ignored
warnings.filterwarnings('ignore')

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O final_vg.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/final_vg.csv
# 100% 2.04M/2.04M [00:00<00:00, 9.15MB/s]

# %%
data = pd.read_csv('final_vg.csv')

# %%
data
# Out:
#         Rank                                           Name Platform    Year  \
# 0       2061                                           1942      NES  1985.0
# 1       9137                   ¡Shin Chan Flipa en colores!       DS  2007.0
# 2      14279              .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 3       8359                     .hack//G.U. Vol.1//Rebirth      PS2  2006.0
# 4       7109                   .hack//G.U. Vol.2//Reminisce      PS2  2006.0
# ...      ...                                            ...      ...     ...
# 16647   7925                             Zumba Fitness Rush     X360  2012.0
# 16648   6279                     Zumba Fitness: World Party      Wii  2013.0
# 16649   6977                     Zumba Fitness: World Party     XOne  2013.0
# 16650  15422                                         Zwei!!      PSP  2008.0
# 16651  12919  Zyuden Sentai Kyoryuger: Game de Gaburincho!!      3DS  2013.0
#
# ...

# %%
data.shape
# Out:
# (16652, 11)

# %% [markdown]
# #bivariate analysis

# %%
data['Name']
# Out:
# 0                                                 1942
# 1                         ¡Shin Chan Flipa en colores!
# 2                    .hack: Sekai no Mukou ni + Versus
# 3                           .hack//G.U. Vol.1//Rebirth
# 4                         .hack//G.U. Vol.2//Reminisce
#                              ...
# 16647                               Zumba Fitness Rush
# 16648                       Zumba Fitness: World Party
# 16649                       Zumba Fitness: World Party
# 16650                                           Zwei!!
# 16651    Zyuden Sentai Kyoryuger: Game de Gaburincho!!
# Name: Name, Length: 16652, dtype: object

# %%
data['Name'].nunique()
# Out:
# 11493

# %%
#most popular games
data['Name'].value_counts()
# Out:
# Name
# Ice Hockey                             41
# Baseball                               17
# Need for Speed: Most Wanted            12
# Ratatouille                             9
# FIFA 14                                 9
#                                        ..
# Indy Racing 2000                        1
# Indycar Series 2005                     1
# inFAMOUS                                1
# inFAMOUS 2                              1
# Inazuma Eleven Strikers 2012 Xtreme     1
# Name: count, Length: 11493, dtype: int64

# %%
data
# Out:
#         Rank                                           Name Platform    Year  \
# 0       2061                                           1942      NES  1985.0
# 1       9137                   ¡Shin Chan Flipa en colores!       DS  2007.0
# 2      14279              .hack: Sekai no Mukou ni + Versus      PS3  2012.0
# 3       8359                     .hack//G.U. Vol.1//Rebirth      PS2  2006.0
# 4       7109                   .hack//G.U. Vol.2//Reminisce      PS2  2006.0
# ...      ...                                            ...      ...     ...
# 16647   7925                             Zumba Fitness Rush     X360  2012.0
# 16648   6279                     Zumba Fitness: World Party      Wii  2013.0
# 16649   6977                     Zumba Fitness: World Party     XOne  2013.0
# 16650  15422                                         Zwei!!      PSP  2008.0
# 16651  12919  Zyuden Sentai Kyoryuger: Game de Gaburincho!!      3DS  2013.0
#
# ...

# %%
ih = data[data['Name']=='Ice Hockey']

# %%
ih
# Out:
#       Rank        Name Platform    Year   Genre   Publisher  NA_Sales  \
# 6073   639  Ice Hockey      NES  1988.0  Sports    Nintendo      0.44
# 6074  4027  Ice Hockey     2600  1980.0  Sports  Activision      0.39
# 6075  4149  Ice Hockey     2600  1991.0  Sports  Activision      0.61
# 6076  4149  Ice Hockey     2600  1992.0  Sports  Activision      0.65
# 6077  4149  Ice Hockey     SNES  1993.0  Sports  Activision      0.68
# 6078  4149  Ice Hockey     SNES  1994.0  Sports  Activision      0.75
# 6079  4149  Ice Hockey     SNES  1995.0  Sports  Activision      0.78
# 6080  4149  Ice Hockey     SNES  1996.0  Sports  Activision      0.76
# 6081  4149  Ice Hockey     SNES  1997.0  Sports  Activision      0.82
# 6082  4149  Ice Hockey     SNES  1998.0  Sports  Activision      0.88
# 6083  4149  Ice Hockey     SNES  1999.0  Sports  Activision      0.85
# 6084  4148  Ice Hockey     SNES  2000.0  Sports  Activision      0.84
# ...

# %%
ih.shape
# Out:
# (41, 11)

# %%
ih['Year']
# Out:
# 6073    1988.0
# 6074    1980.0
# 6075    1991.0
# 6076    1992.0
# 6077    1993.0
# 6078    1994.0
# 6079    1995.0
# 6080    1996.0
# 6081    1997.0
# 6082    1998.0
# 6083    1999.0
# 6084    2000.0
# 6085    2001.0
# 6086    2002.0
# 6087    2003.0
# 6088    2004.0
# 6089    2005.0
# 6090    2006.0
# 6091    2007.0
# 6092    2008.0
# 6093    2009.0
# 6094    2010.0
# 6095    2011.0
# 6096    2012.0
# 6097    2013.0
# 6098    2014.0
# 6099    2015.0
# 6100    2016.0
# 6101    2017.0
# 6102    2018.0
# 6103    2019.0
# 6104    2020.0
# 6105    1990.0
# 6106    1981.0
# 6107    1982.0
# 6108    1983.0
# 6109    1984.0
# 6110    1986.0
# 6111    1987.0
# 6112    1989.0
# 6113    1985.0
# Name: Year, dtype: float64

# %%
#year wise NA sales
sns.lineplot(data=ih,x='Year',y='NA_Sales') #bi-variate
plt.show()

# %%
sns.lineplot(data=ih,x='Year',y='NA_Sales') #bi-variate
plt.xlim(1995,2010)
plt.show()

# %%
sns.lineplot(data=ih,x='Year',y='NA_Sales') #bi-variate
plt.xlim(1995,2010)
plt.xticks(range(1995,2010,3))
plt.show()

# %%
#second popular game =baseball
bh = data[data['Name']=='Baseball']

# %%
bh
# Out:
#      Rank      Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 941   324  Baseball      NES  1980.0  Sports  Nintendo  0.459000  2.320000
# 942   422  Baseball      NES  1983.0  Sports  Nintendo  0.468529  2.697415
# 943   231  Baseball       GB  1985.0  Sports  Nintendo  0.473000  3.074830
# 944  1144  Baseball       GB  1989.0  Sports  Nintendo  0.478448  3.452245
# 945   134  Baseball       GB  1992.0  Sports  Nintendo  0.520000  3.829660
# 946   134  Baseball       GB  1995.0  Sports  Nintendo  0.680000  3.829660
# 947   134  Baseball       PS  1997.0  Sports  Nintendo  0.720000  4.207075
# 948  2321  Baseball      Wii  2003.0  Sports  Nintendo  0.730000  4.584489
# 949   134  Baseball       GB  2004.0  Sports  Nintendo  0.800000  3.829660
# 950  1311  Baseball      Wii  2005.0  Sports  Nintendo  0.710000  4.961904
# 951   134  Baseball     X361  2007.0  Sports  Nintendo  0.530000  3.829660
# ...

# %%
bh.shape
# Out:
# (17, 11)

# %%
sns.lineplot(data=bh, x='Year',y='NA_Sales')
plt.show()

# %%
#lineplot together => plotting og=f two games in a single figure

sns.lineplot(data=ih, x='Year',y='NA_Sales')
sns.lineplot(data=bh, x='Year',y='NA_Sales')
plt.show()

# %%
sns.lineplot(data=ih, x='Year',y='NA_Sales',color='red',label='Ice hockey')
sns.lineplot(data=bh, x='Year',y='NA_Sales',color='green',label='Baseball')
plt.legend()
plt.show()

# %%
xh=data[data['Name']=="Need for Speed: Most Wanted"]
xh.shape
# Out:
# (12, 11)

# %%
sns.lineplot(data=ih, x='Year',y='NA_Sales',color='red',label='Ice hockey')
sns.lineplot(data=bh, x='Year',y='NA_Sales',color='green',label='Baseball')
sns.lineplot(data=xh, x='Year',y='NA_Sales',color='blue',label='NFS')
plt.xlim(2004,2010)
plt.xticks(range(2004,2010,1))
plt.legend()
plt.show()

# %%
sns.lineplot(data=ih, x='Year',y='NA_Sales',color='red',label='Ice hockey')
sns.lineplot(data=bh, x='Year',y='NA_Sales',color='green',label='Baseball')
plt.legend(loc='lower left')
plt.show()

# %%
sns.lineplot(data=ih, x='Year',y='NA_Sales',color='red',label='Ice hockey') #NC
sns.lineplot(data=bh, x='Year',y='NA_Sales',color='green',label='Baseball')
plt.legend(loc='lower left',frameon=False)#documentation to refer
plt.show()

# %%
#NN
data.head()

# %%
#sales and rank
sns.scatterplot(data=data,x='Rank',y='Global_Sales')
plt.show()

# %%
sns.scatterplot(data=data,y='Rank',x='Global_Sales')
plt.show()

# %%
data.head()

# %%
#cc #top3 publishers
top3_pub = data['Publisher'].value_counts().head(3).index
top3_pub

# %%
data['Publisher'].value_counts().index[:3]

# %%
data['Publisher'].value_counts().head(3).values

# %%
#top3 genres
top3_gen = data['Genre'].value_counts().head(3).index

# %%
#top3 platforms
top3_plat = data['Platform'].value_counts().head(3).index

# %%
print(top3_plat)
print(top3_gen)
print(top3_pub)

# %%
data

# %%
top3_data = data[(data['Publisher'].isin(top3_pub)) & ((data['Platform'].isin(top3_plat))) & ((data['Genre'].isin(top3_gen)))]

# %%
top3_data

# %%
sns.countplot(data=top3_data,x='Publisher')  #univariate
plt.show()

# %%
sns.countplot(data=top3_data,x='Publisher',hue='Genre')  #bivariate  #dodged bargraph
plt.show()

# %%
#analysis on global sales => top3_data
top3_data

# %%
sns.boxplot(data=top3_data,y='Global_Sales')

# %%
sns.boxplot(data=top3_data,y='Global_Sales',hue='Publisher')
plt.show()

# %%
sns.boxplot(data=top3_data,y='Global_Sales',hue='Genre')
plt.show()

# %%
sns.boxplot(data=top3_data,y='Global_Sales',x='Publisher', hue='Genre')
plt.show()

# %%
sns.kdeplot(data=top3_data,x='Global_Sales',hue='Publisher')
plt.show()

# %%
#for each of my publisher, if i want to show the avg global sales ?
top3_data[top3_data['Publisher'] == 'Namco Bandai Games']['Global_Sales'].mean()

# %%
#visualize this ?
# count for each unique values in my column => sns.countplot
sns.barplot(data=top3_data,x='Publisher',y='Global_Sales') #mean on the y axis => estimator np.mean
plt.show()

# %%
sns.barplot(data=top3_data,x='Publisher',y='Global_Sales',estimator=np.mean) #mean on the y axis => estimator np.mean
plt.show()

# %%
sns.barplot(data=top3_data,x='Publisher',y='Global_Sales',estimator=np.max) #mean on the y axis => estimator np.mean
plt.show()

# %%
#For the company "Toyota", we want to find which type of vehicle has made the maximum sales.
#Which plot we will prefer to use here?

# %%
#Apple wanted to conduct an analysis and find the relationship between price and number of units sold for it's products.
#Which of the following plots would you prefer? #scatter
