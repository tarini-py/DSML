# %%
'''
# !pip install polars

# !pip install "modin[all]"'''
# Out:
# '\n!pip install polars\n\n!pip install "modin[all]"'

# %%
import pandas as pd
import numpy as np
import polars as pl
#import modin.pandas as mpd

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 72.6MB/s]

# %%
df=pd.read_csv('mckinsey.csv')

# %%
#mdf=mpd.read_csv('mckinsey.csv')
mdf=df

# %%
mdf.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
type(df),type(mdf)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
mdf.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
mdf.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
type(df['country']),type(mdf['country'])
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
mdf.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
mdf[['year','country']]
# Out:
#       year      country
# 0     1952  Afghanistan
# 1     1957  Afghanistan
# 2     1962  Afghanistan
# 3     1967  Afghanistan
# 4     1972  Afghanistan
# ...    ...          ...
# 1699  1987     Zimbabwe
# 1700  1992     Zimbabwe
# 1701  1997     Zimbabwe
# 1702  2002     Zimbabwe
# 1703  2007     Zimbabwe
#
# [1704 rows x 2 columns]

# %%
mdf.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
mdf.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].head(20)
# Out:
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12        Albania
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# Name: country, dtype: object

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].nunique()
# Out:
# 142

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan           12
# Albania               12
# Algeria               12
# Angola                12
# Argentina             12
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen, Rep.           12
# Zambia                12
# Zimbabwe              12
# Name: count, Length: 142, dtype: int64

# %%
df.rename(columns={'Country':'country'},inplace=True)

# %%
df['continent'].nunique(),df['continent'].unique()
# Out:
# (5, array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object))

# %%
df['continent'].value_counts().to_frame()
# Out:
#            count
# continent
# Africa       624
# Asia         396
# Europe       360
# Americas     300
# Oceania       24

# %%
df['continent'].value_counts().to_frame().loc['Asia','count']
# Out:
# np.int64(396)

# %%
df.drop(columns=['continent'])
# Out:
#           country  year  population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df['new_year']=df['year']+7

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  new_year
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314      1959
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030      1964
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710      1969
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138      1974
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106      1979
# ...           ...   ...         ...       ...       ...         ...       ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306      1994
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786      1999
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960      2004
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623      2009
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298      2014
#
# [1704 rows x 7 columns]

# %%
df['GDP']=df['population']*df['gdp_cap']

# %%
df["empty"]=" "

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  new_year  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314      1959
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030      1964
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710      1969
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138      1974
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106      1979
# ...           ...   ...         ...       ...       ...         ...       ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306      1994
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786      1999
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960      2004
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623      2009
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298      2014
#
#                GDP empty
# ...

# %%
df['new_col']=[i for i in range(df.shape[0])]

# %%
df.drop(columns=['new_col','empty','new_year','GDP'],inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index=range(1,df.shape[0]+1)

# %%
df.index
# Out:
# RangeIndex(start=1, stop=1705, step=1)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[0]==df.loc[1]
# Out:
# country       True
# year          True
# population    True
# continent     True
# life_exp      True
# gdp_cap       True
# Name: 1, dtype: bool

# %%
df[0:4]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4  Afghanistan  1967    11537966      Asia    34.020  836.197138

# %%
pd.DataFrame(df,columns=['gdp_cap','year'])
# Out:
#          gdp_cap  year
# 1     779.445314  1952
# 2     820.853030  1957
# 3     853.100710  1962
# 4     836.197138  1967
# 5     739.981106  1972
# ...          ...   ...
# 1700  706.157306  1987
# 1701  693.420786  1992
# 1702  792.449960  1997
# 1703  672.038623  2002
# 1704  469.709298  2007
#
# [1704 rows x 2 columns]

# %%
df.loc[:,['gdp_cap','year']]
# Out:
#          gdp_cap  year
# 1     779.445314  1952
# 2     820.853030  1957
# 3     853.100710  1962
# 4     836.197138  1967
# 5     739.981106  1972
# ...          ...   ...
# 1700  706.157306  1987
# 1701  693.420786  1992
# 1702  792.449960  1997
# 1703  672.038623  2002
# 1704  469.709298  2007
#
# [1704 rows x 2 columns]

# %%
df.iloc[:2,:2]
# Out:
#        country  year
# 1  Afghanistan  1952
# 2  Afghanistan  1957

# %%
df.loc[:2,'year':'gdp_cap']
# Out:
#    year  population continent  life_exp     gdp_cap
# 1  1952     8425333      Asia    28.801  779.445314
# 2  1957     9240934      Asia    30.332  820.853030

# %%
type(df['continent']),df['continent'].nunique()
# Out:
# (pandas.core.series.Series, 5)

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df.nunique()
# Out:
# country        142
# year            12
# population    1704
# continent        5
# life_exp      1626
# gdp_cap       1704
# dtype: int64

# %%
df.iloc[:20]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 1   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 2   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 3   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 4   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 5   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 6   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 7   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 8   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 9   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 10  Afghanistan  1997    22227415      Asia    41.763   635.341351
# 11  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 12  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 13      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
#df[['continent','country']]
df.loc[1:4,'country':'continent']
# Out:
#        country  year  population continent
# 1  Afghanistan  1952     8425333      Asia
# 2  Afghanistan  1957     9240934      Asia
# 3  Afghanistan  1962    10267083      Asia
# 4  Afghanistan  1967    11537966      Asia

# %%
df.loc[[2,3],['country','continent']]
# Out:
#        country continent
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df = pd.DataFrame({'emp_id':[1, 2], 'name': ['Ram', 'Shyam'], 'dept':['IT', 'Ops']})
df
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %%
df = pd.DataFrame([[1, "Ram", "IT"]], columns = ["emp_id", "name", "dept"])
df
# Out:
#    emp_id name dept
# 0       1  Ram   IT

# %%
df = pd.DataFrame([[1, "Ram", "IT"], [2, "Shyam", "Ops"]], columns = ["emp_id", "name", "dept"])
df
# Out:
#    emp_id   name dept
# 0       1    Ram   IT
# 1       2  Shyam  Ops

# %% [markdown]
# https://drive.google.com/file/d/1UcWItyfVGL-mPlnR002bDRx_rdkSbgGq/view?usp=drive_link

# %%
# !gdown 1UcWItyfVGL-mPlnR002bDRx_rdkSbgGq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UcWItyfVGL-mPlnR002bDRx_rdkSbgGq
# To: /content/mtcars.csv
# 100% 1.70k/1.70k [00:00<00:00, 8.27MB/s]

# %%
df=pd.read_csv('mtcars.csv')
df.head(3)
# Out:
#            model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
df.rename(columns={'model':'Model','cyl':'CYL'}).head(2)
# Out:
#            Model   mpg  CYL   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110   3.9  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1     4
#
#    carb
# 0     4
# 1     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.keys()
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.loc[9::-3]
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 9        Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# 6      Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
#
#    carb
# 9     4
# 6     4
# 3     1
# 0     4

# %%
df.iloc[9::-3]
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 9        Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# 6      Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
#
#    carb
# 9     4
# 6     4
# 3     1
# 0     4

# %%
df.index=[i for i in range(1,df.shape[0]+1)]

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 1             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 2         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 3            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 4        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.loc[9::-3]
# Out:
#         model   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 9    Merc 230  22.8    4  140.8   95  3.92  3.15  22.90   1   0     4     2
# 6     Valiant  18.1    6  225.0  105  2.76  3.46  20.22   1   0     3     1
# 3  Datsun 710  22.8    4  108.0   93  3.85  2.32  18.61   1   1     4     1

# %%
df.iloc[9::-3]
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 10        Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# 7       Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 4   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 1        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
#
#     carb
# 10     4
# 7      4
# 4      1
# 1      4

# %%
a=pd.Series(['a','b','c'], index=[1,2,2])

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[2]
# Out:
# 2    b
# 2    c
# dtype: object

# %%
df=pd.read_csv('mckinsey.csv')

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
pd.concat((df,df))
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [3408 rows x 6 columns]

# %%
df.shape[0]
# Out:
# 1704

# %%
len(df)
# Out:
# 1704

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[len(df)]=["Tarini",	2007,	12311143,	"Prasad",	43.487,	469.709298]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Tarini  2007    12311143    Prasad    43.487  469.709298
#
# [1705 rows x 6 columns]

# %%
df.loc[3000]=["Tarini",	2007,	12311143,	"Prasad",	43.487,	469.709298]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Tarini  2007    12311143    Prasad    43.487  469.709298
# 3000       Tarini  2007    12311143    Prasad    43.487  469.709298
#
# [1706 rows x 6 columns]

# %%
df.drop(index=[3000,1704],inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[1704]=["Tarini",	2007,	12311143,	"Prasad",	43.487,	469.709298]

# %%
df.loc[1704]=["Prasad",	2007,	12311143,	"Prasad",	43.487,	469.709298]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Prasad  2007    12311143    Prasad    43.487  469.709298
#
# [1705 rows x 6 columns]

# %%
df.loc[len(df)]=["Prasad",	2007,	12311143,	"Prasad",	43.487,	469.709298]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Prasad  2007    12311143    Prasad    43.487  469.709298
# 1705       Prasad  2007    12311143    Prasad    43.487  469.709298
#
# [1706 rows x 6 columns]

# %%
df.drop([1704,1705,1706,1707])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-322617633.py in <cell line: 0>()
# ----> 1 df.drop([1704,1705,1706,1707])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Prasad  2007    12311143    Prasad    43.487  469.709298
# 1705       Prasad  2007    12311143    Prasad    43.487  469.709298
#
# [1706 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# 1705     True
# Length: 1706, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      country  year  population continent  life_exp     gdp_cap
# 1705  Prasad  2007    12311143    Prasad    43.487  469.709298

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Prasad  2007    12311143    Prasad    43.487  469.709298
#
# [1705 rows x 6 columns]

# %%
df.sort_values(by='gdp_cap',ascending=False).head(20)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 853             Kuwait  1957      212846      Asia    58.033  113523.13290
# 856             Kuwait  1972      841934      Asia    67.712  109347.86700
# 852             Kuwait  1952      160000      Asia    55.565  108382.35290
# 854             Kuwait  1962      358266      Asia    60.470   95458.11176
# 855             Kuwait  1967      575003      Asia    64.624   80894.88326
# 857             Kuwait  1977     1140357      Asia    69.343   59265.47714
# 1151            Norway  2007     4627926    Europe    80.196   49357.19017
# 863             Kuwait  2007     2505559      Asia    77.588   47306.98978
# 1367         Singapore  2007     4553009      Asia    79.972   47143.17964
# 1150            Norway  2002     4535591    Europe    79.050   44683.97525
# 1619     United States  2007   301139947  Americas    78.242   42951.65309
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704       Prasad  2007    12311143    Prasad    43.487  469.709298
# 1705       Prasad  2007    12311143    Prasad    43.487  469.709298
#
# [1706 rows x 6 columns]

# %%
df.loc[0:4,'year':'gdp_cap':2]
# Out:
#    year continent     gdp_cap
# 0  1952      Asia  779.445314
# 1  1957      Asia  820.853030
# 2  1962      Asia  853.100710
# 3  1967      Asia  836.197138
# 4  1972      Asia  739.981106

# %%
df['gdp_cap'].mean()
# Out:
# np.float64(7207.4189712669995)

# %%
df['gdp_cap'].max()
# Out:
# 113523.1329

# %%
df['gdp_cap'].min(),df['gdp_cap'].std()
# Out:
# (241.1658765, 9854.376801463857)

# %%
temp=df.sort_values(by='gdp_cap',ascending=False)

# %%
temp=df.sort_values(by=['year','gdp_cap'],ascending=[False,True])

# %%
temp
# Out:
#                country  year  population continent  life_exp        gdp_cap
# 335   Congo, Dem. Rep.  2007    64606759    Africa    46.462     277.551859
# 899            Liberia  2007     3193942    Africa    45.678     414.507341
# 215            Burundi  2007     8390505    Africa    49.580     430.070692
# 1704            Prasad  2007    12311143    Prasad    43.487     469.709298
# 1705            Prasad  2007    12311143    Prasad    43.487     469.709298
# ...                ...   ...         ...       ...       ...            ...
# 1092       New Zealand  1952     1994794   Oceania    69.390   10556.575660
# 240             Canada  1952    14785584  Americas    68.750   11367.161120
# 1608     United States  1952   157553000  Americas    68.440   13990.482080
# 1476       Switzerland  1952     4815000    Europe    69.620   14734.232750
# 852             Kuwait  1952      160000      Asia    55.565  108382.352900
#
# [1706 rows x 6 columns]

# %%
temp.reset_index(drop=True,inplace=True)

# %%
temp.to_csv('temp.csv',index=False)

# %%
temp.to_csv('temp.csv')

# %%
df.sort_values?
