# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

data = {
    'name': ['Jim', 'Clarke', 'Kent', 'Mark'],
    'username': ['itsjimhere', 'clark002', 'itskentment', 'markyoumustknow'],
    'userid': [20, 10, 86, 21]
}

df = pd.DataFrame(data)
df
# Out:
#      name         username  userid
# 0     Jim       itsjimhere      20
# 1  Clarke         clark002      10
# 2    Kent      itskentment      86
# 3    Mark  markyoumustknow      21

# %%
def check(x):
    return x['name'].lower() in x['username']

~df.apply(check,axis=1)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
import pandas as pd

data = {
    'name': ['Elon', 'Jeff', 'Bill', 'Falguni'],
    'gender': ['M', 'F', 'M', 'F'],
    'income': [53000.0, 28000.0, 25000.0, 44000.0]
}

df = pd.DataFrame(data)

# %%
result=df.groupby('gender')['income'].mean()

# %%
result
# Out:
# gender
# F    36000.0
# M    39000.0
# Name: income, dtype: float64

# %%
result.iloc[:]
# Out:
# gender
# F    36000.0
# M    39000.0
# Name: income, dtype: float64

# %%
import pandas as pd

data = {
    'name': ['Luffy', 'Chopper', 'Zoro', 'Sanji'],
    'marks': [15, 89, 33, 32]
}

df = pd.DataFrame(data)

# %%
df[df['marks']>=33]['name']
# Out:
# 1    Chopper
# 2       Zoro
# Name: name, dtype: object

# %%
import pandas as pd

data = {
    'cust_id': [101, 102, 103, 104],
    'name': ['rick', 'morty', 'pickle', 'jerry'],
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    cust_id    name
# 0      101    rick
# 1      102   morty
# 2      103  pickle
# 3      104   jerry

# %%
df.isin([101, 102, 120])
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
df.isin({'cust_id': [101, 102]})
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
df.name.isin(['rick'])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: name, dtype: bool

# %%
df.isin(df.cust_id)
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False

# %%
import pandas as pd

data = {'marks': {0: 55,   1: 61,   2: 67,   3: 68,   4: 83,   5: 69,   6: 89,   7: 68,   8: 59,   9: 49,   10: 40,   11: 48},  'roll_no': {0: 1,   1: 1,   2: 3,   3: 1,   4: 2,   5: 2,   6: 2,   7: 3,   8: 3,   9: 3,   10: 1,   11: 2},  'subject': {0: 'ML',   1: 'NN',   2: 'NN',   3: 'DL',   4: 'DL',   5: 'NN',   6: 'ML',   7: 'Prob',   8: 'DL',   9: 'ML',   10: 'Prob',   11: 'Prob'}}

df = pd.DataFrame(data)

# %%
df
# Out:
#     marks  roll_no subject
# 0      55        1      ML
# 1      61        1      NN
# 2      67        3      NN
# 3      68        1      DL
# 4      83        2      DL
# 5      69        2      NN
# 6      89        2      ML
# 7      68        3    Prob
# 8      59        3      DL
# 9      49        3      ML
# 10     40        1    Prob
# 11     48        2    Prob

# %%
max_marks = df.groupby('subject')['marks'].max()
max_marks
# Out:
# subject
# DL      83
# ML      89
# NN      69
# Prob    68
# Name: marks, dtype: int64

# %%
max_marks = max_marks.reset_index()
max_marks
# Out:
#   subject  marks
# 0      DL     83
# 1      ML     89
# 2      NN     69
# 3    Prob     68

# %%
result=pd.merge(max_marks,df,on=['subject','marks'],how='inner')
result
# Out:
#   subject  marks  roll_no
# 0      DL     83        2
# 1      ML     89        2
# 2      NN     69        2
# 3    Prob     68        3

# %%
result.drop(['subject_y'],inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1174775294.py in <cell line: 0>()
# ----> 1 result.drop(['subject_y'],inplace=True,axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
result.rename(columns={'subject_x':'subject'},inplace=True)

# %%
result

# %%
# !gdown 1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# To: /content/sales.csv
# 100% 94.9M/94.9M [00:00<00:00, 208MB/s]

# %%
df=pd.read_csv('sales.csv')

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.groupby('Description')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545
# WHITE HANGING HEART T-LIGHT HOLDER     93050
# ASSORTED COLOUR BIRD ORNAMENT          81306
# JUMBO BAG RED RETROSPOT                78090
# BROCADE RING PURSE                     70700
#                                        ...
# Unsaleable, destroyed.                -15644
# missing                               -16467
# printing smudges/thrown away          -19200
# given away                            -20000
# ?                                     -26757
# Name: Quantity, Length: 5698, dtype: int64

# %%
df['new']=df['Quantity']*df['Price']

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country     new
# ...

# %%
df.sort_values(by='new',ascending=False).iloc[0,:]
# Out:
# Invoice                             581483
# StockCode                            23843
# Description    PAPER CRAFT , LITTLE BIRDIE
# Quantity                             80995
# InvoiceDate            2011-12-09 09:15:00
# Price                                 2.08
# Customer ID                        16446.0
# Country                     United Kingdom
# new                               168469.6
# Name: 1065882, dtype: object

# %%
df[df['Country']=="United Kingdom"]['StockCode'].nunique()
# Out:
# 5303

# %%
import pandas as pd

data = {
    'Name': ['Himanshu', 'Robert', 'Karie', 'Rohan', 'John'],
    'Age': [15, 14, 15, 16, 17],
    'Percentage': [80, 77, 83, 45, 70],
    'Stream': ['Commerce', 'Science', 'Arts', 'Commerce', 'Science']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#        Name  Age  Percentage    Stream
# 0  Himanshu   15          80  Commerce
# 1    Robert   14          77   Science
# 2     Karie   15          83      Arts
# 3     Rohan   16          45  Commerce
# 4      John   17          70   Science

# %%
df[((df['Stream']=='Commerce') | (df['Stream']=='Arts')) & (df['Percentage']>=75)]['Name']
# Out:
# 0    Himanshu
# 2       Karie
# Name: Name, dtype: object

# %%
import pandas as pd

data = {
    'ord_no': [70001, 70009, 70002, 70004, 70007, 70005, 70008, 70010, 70003, 70012, 70011, 70013],
    'purch_amt': [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    'ord_date': ['2012-10-05', '2012-09-10', '2012-10-05', '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3005, 3001, 3002, 3009, 3005, 3007, 3002, 3004, 3009, 3008, 3003, 3002],
    'salesman_id': [5002, 5005, 5001, 5003, 5002, 5001, 5001, 5006, 5003, 5002, 5007, 5001]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3005         5002
# 1    70009     270.65  2012-09-10         3001         5005
# 2    70002      65.26  2012-10-05         3002         5001
# 3    70004     110.50  2012-08-17         3009         5003
# 4    70007     948.50  2012-09-10         3005         5002
# 5    70005    2400.60  2012-07-27         3007         5001
# 6    70008    5760.00  2012-09-10         3002         5001
# 7    70010    1983.43  2012-10-10         3004         5006
# 8    70003    2480.40  2012-10-10         3009         5003
# 9    70012     250.45  2012-06-27         3008         5002
# 10   70011      75.29  2012-08-17         3003         5007
# 11   70013    3045.60  2012-04-25         3002         5001

# %%
result=df.groupby(['salesman_id','customer_id'])['ord_no'].count()
result
# Out:
# salesman_id  customer_id
# 5001         3002           3
#              3007           1
# 5002         3005           2
#              3008           1
# 5003         3009           2
# 5005         3001           1
# 5006         3004           1
# 5007         3003           1
# Name: ord_no, dtype: int64

# %%
result.reset_index()
# Out:
#    salesman_id  customer_id  ord_no
# 0         5001         3002       3
# 1         5001         3007       1
# 2         5002         3005       2
# 3         5002         3008       1
# 4         5003         3009       2
# 5         5005         3001       1
# 6         5006         3004       1
# 7         5007         3003       1

# %%
s="How much wood would a woodchuck chuck if a woodchuck could chuck wood"

# %%
print(pd.Series(s.split()).value_counts().sort_index())
# Out:
# How          1
# a            2
# chuck        2
# could        1
# if           1
# much         1
# wood         2
# woodchuck    2
# would        1
# Name: count, dtype: int64

# %% [markdown]
# # IMDB Case study

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 77.6MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 90.4MB/s]

# %%
#loading these files using pandas
movies = pd.read_csv('movies.csv',index_col=0)
directors = pd.read_csv('directors.csv',index_col = 0)

# %%
movies.head(5)
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors.head(3)
# Out:
#     director_name    id gender
# 0   James Cameron  4762   Male
# 1  Gore Verbinski  4763   Male
# 2      Sam Mendes  4764   Male

# %%
movies.shape,directors.shape
# Out:
# ((1465, 11), (2349, 3))

# %%
movies['director_id'].nunique(),directors['id'].nunique()
# Out:
# (199, 2349)

# %%
np.all(movies['director_id'].isin(directors['id']))
# Out:
# np.True_

# %%
directors['id'].isin(movies['director_id']).value_counts()
# Out:
# id
# False    2150
# True      199
# Name: count, dtype: int64

# %%
df=pd.merge(movies,directors,left_on='director_id',right_on='id',how='left',suffixes=['_movies','_directors'])
df
# Out:
#       id_movies     budget  popularity     revenue  \
# 0         43597  237000000         150  2787965087
# 1         43598  300000000         139   961000000
# 2         43599  245000000         107   880674609
# 3         43600  250000000         112  1084939099
# 4         43602  258000000         115   890871626
# ...         ...        ...         ...         ...
# 1460      48363          0           3      321952
# 1461      48370      27000          19     3151130
# 1462      48375          0           7           0
# 1463      48376          0           3           0
# 1464      48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
def is_null(x):
  return sum(x.isnull())

df.apply(is_null,axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1460    0
# 1461    0
# 1462    0
# 1463    0
# 1464    1
# Length: 1465, dtype: int64

# %%
df
# Out:
#       id_movies     budget  popularity     revenue  \
# 0         43597  237000000         150  2787965087
# 1         43598  300000000         139   961000000
# 2         43599  245000000         107   880674609
# 3         43600  250000000         112  1084939099
# 4         43602  258000000         115   890871626
# ...         ...        ...         ...         ...
# 1460      48363          0           3      321952
# 1461      48370      27000          19     3151130
# 1462      48375          0           7           0
# 1463      48376          0           3           0
# 1464      48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# ...

# %%
def encode(df):
  if df=='Male':
    return 1
  else:
    return 0

#df.apply(encode,axis=1) #works
df['gender'].apply(encode)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1460    1
# 1461    1
# 1462    1
# 1463    1
# 1464    0
# Name: gender, Length: 1465, dtype: int64

# %%
df.sort_values(by='popularity',ascending=False).iloc[0:10,4]
# Out:
# 58                                          Interstellar
# 78                                    Mad Max: Fury Road
# 119    Pirates of the Caribbean: The Curse of the Bla...
# 120                The Hunger Games: Mockingjay - Part 1
# 45                                       The Dark Knight
# 59                                             Inception
# 162                                          The Martian
# 5                     Batman v Superman: Dawn of Justice
# 0                                                 Avatar
# 383                                           Fight Club
# Name: title, dtype: object

# %%
df[df['vote_average']==df['vote_average'].max()]
# Out:
#       id_movies    budget  popularity    revenue             title  \
# 383       44259  63000000         146  100853753        Fight Club
# 901       45415  22000000         104  321365567  Schindler's List
# 1284      46829   8000000         121  213928762      Pulp Fiction
#
#       vote_average  vote_count  director_id  year month       day  \
# 383            8.3        9413         4829  1999   Oct    Friday
# 901            8.3        4329         4799  1993   Nov    Monday
# 1284           8.3        8428         4927  1994   Oct  Saturday
#
#           director_name  id_directors gender
# 383       David Fincher          4829   Male
# 901    Steven Spielberg          4799   Male
# 1284  Quentin Tarantino          4927   Male

# %%
df.groupby('year')['title'].count()
# Out:
# year
# 1976     3
# 1977     6
# 1978     5
# 1979     4
# 1980     8
# 1981    11
# 1982    10
# 1983     9
# 1984    10
# 1985    14
# 1986    11
# 1987    12
# 1988    13
# 1989    18
# 1990    18
# 1991    12
# 1992    22
# 1993    18
# 1994    31
# 1995    33
# 1996    46
# 1997    46
# 1998    45
# 1999    64
# 2000    59
# 2001    62
# 2002    69
# 2003    58
# 2004    61
# 2005    71
# 2006    73
# 2007    54
# 2008    67
# 2009    66
# 2010    63
# 2011    67
# 2012    49
# 2013    57
# 2014    53
# 2015    41
# 2016    26
# Name: title, dtype: int64

# %%
df1=df.groupby('year')['budget'].max().reset_index()
df1
# Out:
#     year     budget
# 0   1976    3800000
# 1   1977   20000000
# 2   1978   55000000
# 3   1979   35000000
# 4   1980   27000000
# 5   1981   28000000
# 6   1982   28000000
# 7   1983   40600000
# 8   1984   58000000
# 9   1985   31000000
# 10  1986   25000000
# 11  1987   40000000
# 12  1988   28000000
# 13  1989   70000000
# 14  1990   70000000
# 15  1991  100000000
# 16  1992   80000000
# 17  1993   85000000
# 18  1994  115000000
# 19  1995  175000000
# 20  1996  100000000
# 21  1997  200000000
# 22  1998  140000000
# 23  1999  170000000
# 24  2000  125000000
# 25  2001  140000000
# 26  2002  140000000
# 27  2003  150000000
# 28  2004  200000000
# 29  2005  207000000
# 30  2006  270000000
# 31  2007  300000000
# 32  2008  225000000
# 33  2009  237000000
# 34  2010  200000000
# 35  2011  380000000
# 36  2012  250000000
# 37  2013  255000000
# 38  2014  250000000
# 39  2015  245000000
# 40  2016  250000000

# %%
pd.merge(df,df1,on=['year','budget'],how='inner').sort_values(by='year')
# Out:
#     id_movies     budget  popularity     revenue  \
# 48      47409    3800000          17    23689877
# 46      45684   20000000          52   303788635
# 35      44410   55000000          48   300218018
# 38      45107   35000000          10    31755742
# 44      45350   27000000          44   115229890
# 42      45310   28000000          26   195312802
# 43      45322   28000000          94    33139618
# 47      46771   40600000          34    90400000
# 36      44615   58000000           8    25928721
# 39      45126   31000000          13   128499205
# 40      45206   25000000          12    38748395
# 45      45515   25000000          29    11000000
# 37      44797   40000000          23   191185897
# 41      45299   28000000          66   140767956
# 34      44184   70000000          24    90000098
# 33      44170   70000000          57   240031094
# 28      43876  100000000         101   520000000
# 32      44025   80000000          59   280000000
# ...

# %%
pd.merge(df,df1,on=['year','budget'],how='inner')
# Out:
#     id_movies     budget  popularity     revenue  \
# 0       43597  237000000         150  2787965087
# 1       43598  300000000         139   961000000
# 2       43599  245000000         107   880674609
# 3       43600  250000000         112  1084939099
# 4       43606  250000000         155   873260194
# 5       43607  270000000          57   391081192
# 6       43610  255000000          49    89289910
# 7       43612  225000000          53   419651413
# 8       43614  380000000         135  1045713802
# 9       43616  250000000         120   956019788
# 10      43618  200000000          37   310669540
# 11      43621  207000000          61   550000000
# 12      43622  200000000         100  1845034188
# 13      43627  200000000          35   783766341
# 14      43629  200000000          78  1025491110
# 15      43643  250000000         118   747862775
# 16      43667  170000000          40   222104681
# 17      43672  175000000          44   264218220
# ...
