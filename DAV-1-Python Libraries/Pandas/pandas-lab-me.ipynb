# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 58.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 54.7MB/s]

# %%
movies = pd.read_csv('movies.csv', index_col=0)
directors = pd.read_csv('directors.csv', index_col=0)

# %%
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 5     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 4736  48363          0           3      321952
# 4743  48370      27000          19     3151130
# 4748  48375          0           7           0
# 4749  48376          0           3           0
# 4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
df=pd.merge(movies,directors,left_on='director_id',right_on='id',how='inner')

# %%
df.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
df.sort_values(by='year')
# Out:
#        id_x     budget  popularity    revenue              title  \
# 1379  47409    3800000          17   23689877            Network
# 912   45435    2800000          25   60922980           The Omen
# 1427  47934    1300000          58   28262574        Taxi Driver
# 1456  48321      10000          20    7000000         Eraserhead
# 1368  47336    4000000          35   38251425         Annie Hall
# ...     ...        ...         ...        ...                ...
# 38    43653  185000000          65  343471816   Star Trek Beyond
# 44    43661  178000000         139  543934787  X-Men: Apocalypse
# 50    43669  175000000          90  745000000      Suicide Squad
# 54    43675  175000000          94  966550600    The Jungle Book
# 980   45638   22000000          39   63647656      Hail, Caesar!
#
#       vote_average  vote_count  director_id  year month        day  \
# 1379           7.7         381         5615  1976   Nov     Monday
# ...

# %%
df.year.max()-df.year.min()
# Out:
# 40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  id_y           1465 non-null   int64
#  13  gender         1341 non-null   object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 160.4+ KB

# %%
df['release_date']=df.day+'-'+df.month+'-'+df.year.astype('str')

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.gender.value_counts()
# Out:
# gender
# Male      1309
# Female      32
# Name: count, dtype: int64

# %%
len(df.gender)
# Out:
# 1465

# %%
100*df.gender.value_counts()[0]/len(df.gender)
# Out:
# /tmp/ipython-input-4049077986.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   100*df.gender.value_counts()[0]/len(df.gender)
# np.float64(89.35153583617748)

# %%
1309/1465
# Out:
# 0.8935153583617748

# %%
df.groupby(['year'])['title'].count().loc[2010]
# Out:
# np.int64(63)

# %%
sum(df.year==2010)
# Out:
# 63

# %%
df[df.year>=2010]['director_id'].nunique()
# Out:
# 163

# %%
df.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender  \
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
df[df.title=='Spider-Man 3']['director_name'].iloc[0]
# Out:
# 'Sam Raimi'

# %%
sum(df[((df.year>=2005) & (df.year<=2010))].director_name=='James Cameron')
# Out:
# 1

# %%
df.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender  \
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
df.sort_values(by='popularity',ascending=False).iloc[:10,:].sort_values(by='vote_average',ascending=False).iloc[1,:]
# Out:
# id_x                          43662
# budget                    185000000
# popularity                      187
# revenue                  1004558444
# title               The Dark Knight
# vote_average                    8.2
# vote_count                    12002
# director_id                    4765
# year                           2008
# month                           Jul
# day                       Wednesday
# director_name     Christopher Nolan
# id_y                           4765
# gender                         Male
# release_date     Wednesday-Jul-2008
# Name: 45, dtype: object

# %%
x=df.sort_values(by='popularity',ascending=False).head(10)

# %%
y=df.sort_values(by='vote_average',ascending=False).head(10)

# %%
sum(x.isin(y)['title'])
# Out:
# 4

# %%
df.nlargest(10,'popularity').isin(df.nlargest(10,'vote_average'))['title'].sum()
# Out:
# np.int64(4)

# %%
df[df.director_name=='Christopher Nolan']['year'].value_counts().sort_values(ascending=False)
# Out:
# year
# 2012    1
# 2008    1
# 2014    1
# 2010    1
# 2005    1
# 2002    1
# 2006    1
# 2000    1
# Name: count, dtype: int64

# %%
df[df['director_name']=='Christopher Nolan'].groupby(by='year')['title'].count()
# Out:
# year
# 2000    1
# 2002    1
# 2005    1
# 2006    1
# 2008    1
# 2010    1
# 2012    1
# 2014    1
# Name: title, dtype: int64

# %%
def d(director_name):
  return df[df.director_name==director_name]['year'].value_counts().sort_values(ascending=False)

# %%
d('Christopher Nolan')
# Out:
# year
# 2012    1
# 2008    1
# 2014    1
# 2010    1
# 2005    1
# 2002    1
# 2006    1
# 2000    1
# Name: count, dtype: int64

# %%
df.year.max()
# Out:
# 2016

# %%
df.year.min()
# Out:
# 1976

# %%
decade=[1970,1980,1990,2000,2010,2020]
labels=['70s','80s','90s','00s','10s']
df['decade']=pd.cut(df.year,decade,labels=labels)

# %%
df.decade.value_counts(ascending=False)
# Out:
# decade
# 00s    644
# 90s    376
# 10s    293
# 80s    126
# 70s     26
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender  \
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.year.max()-df.year.min()
# Out:
# 40

# %%
len(df.year.unique())
# Out:
# 41

# %%
sum(df.year==2010)
# Out:
# 63

# %%
df[df.year>=2010].director_name.nunique()
# Out:
# 163

# %%
sample = movies[movies["year"] >= 2010]
ids = sample["director_id"].unique()
names = directors[directors["id"].isin(ids)]["director_name"]

# %%
names
# Out:
# 1            Gore Verbinski
# 2                Sam Mendes
# 3         Christopher Nolan
# 5                 Sam Raimi
# 9               Zack Snyder
#                ...
# 1132          Brad Anderson
# 1189         Michael Polish
# 1208          Paul Schrader
# 1294    Darren Lynn Bousman
# 1442      Nicole Holofcener
# Name: director_name, Length: 163, dtype: object

# %%
sample = movies[movies["year"] >= 2010]
ids = sample["director_id"]
names = directors[directors["id"] == ids]["director_name"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1517825871.py in <cell line: 0>()
#       1 sample = movies[movies["year"] >= 2010]
#       2 ids = sample["director_id"]
# ----> 3 names = directors[directors["id"] == ids]["director_name"]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# ...

# %%
ids = movies["director_id"].unique()
names = directors[directors["id"].isin(ids) & (movies["year"] >= 2010)]["director_name"]
# Out:
# /tmp/ipython-input-3978748766.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   names = directors[directors["id"].isin(ids) & (movies["year"] >= 2010)]["director_name"]

# %%
len(names)
# Out:
# 45

# %%
data=df

# %%
data.loc[data["title"] == "Spider-Man 3", "director_name"]
# Out:
# 4    Sam Raimi
# Name: director_name, dtype: object

# %%
data[data["title"] == "Spider-Man 3"]["director_name"]
# Out:
# 4    Sam Raimi
# Name: director_name, dtype: object

# %%
directors[directors['id'] == data[data['title'] == 'Spider-Man 3']['director_id'].iloc[0]]['director_name']
# Out:
# 5    Sam Raimi
# Name: director_name, dtype: object

# %%
data.query("title == 'Spider-Man 3'").get('director_name')
# Out:
# 4    Sam Raimi
# Name: director_name, dtype: object

# %%
data[data["title"] == "Spider-Man 3"]["director_name"]
# Out:
# 4    Sam Raimi
# Name: director_name, dtype: object

# %%
data.loc[data["title"] == "Spider-Man 3", "director_name"]
# Out:
# 4    Sam Raimi
# Name: director_name, dtype: object

# %%
df.columns
# Out:
# Index(['id_x', 'budget', 'popularity', 'revenue', 'title', 'vote_average',
#        'vote_count', 'director_id', 'year', 'month', 'day', 'director_name',
#        'id_y', 'gender', 'release_date', 'decade'],
#       dtype='object')

# %%
df[(df.director_name=="James Cameron") & (df.year>=2005) & (df.year<=2010)]
# Out:
#     id_x     budget  popularity     revenue   title  vote_average  vote_count  \
# 0  43597  237000000         150  2787965087  Avatar           7.2       11800
#
#    director_id  year month       day  director_name  id_y gender  \
# 0         4762  2009   Dec  Thursday  James Cameron  4762   Male
#
#         release_date        decade
# 0  Thursday-Dec-2009  (2000, 2010]

# %%
x=df.nlargest(10,'popularity')['title']
x
# Out:
# 58                                          Interstellar
# 78                                    Mad Max: Fury Road
# 119    Pirates of the Caribbean: The Curse of the Bla...
# 120                The Hunger Games: Mockingjay - Part 1
# 45                                       The Dark Knight
# 59                                             Inception
# 162                                          The Martian
# 5                     Batman v Superman: Dawn of Justice
# 0                                                 Avatar
# 383                                           Fight Club
# Name: title, dtype: object

# %%
y=df.nlargest(10,'vote_average').title
y
# Out:
# 383                                        Fight Club
# 901                                  Schindler's List
# 1284                                     Pulp Fiction
# 45                                    The Dark Knight
# 459                                      Forrest Gump
# 917                                        GoodFellas
# 58                                       Interstellar
# 59                                          Inception
# 199     The Lord of the Rings: The Return of the King
# 785                                             Se7en
# Name: title, dtype: object

# %%
x[x.isin(y)]
# Out:
# 58        Interstellar
# 45     The Dark Knight
# 59           Inception
# 383         Fight Club
# Name: title, dtype: object

# %%
df[df.director_name=='Christopher Nolan'].groupby('year')['title'].count()
# Out:
# year
# 2000    1
# 2002    1
# 2005    1
# 2006    1
# 2008    1
# 2010    1
# 2012    1
# 2014    1
# Name: title, dtype: int64

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.decade.value_counts(ascending=False)
# Out:
# decade
# 00s    644
# 90s    376
# 10s    293
# 80s    126
# 70s     26
# Name: count, dtype: int64

# %%
# Out:
# Interval(2000, 2010, closed='right')

# %%
df[df.decade=="00s"].groupby('director_name')[['revenue','budget']].apply(lambda x: x['revenue']-x['budget']).sort_values(ascending=False)
# Out:
# director_name
# James Cameron   0      2550965087
# Peter Jackson   199    1024888979
# Gore Verbinski  8       865659812
# Chris Columbus  117     851475550
# Peter Jackson   200     847287400
#                           ...
# Richard Donner  286     -60519261
# Bobby Farrelly  352     -61403089
# Mike Newell     374     -65000000
# Peter Hyams     289     -74010360
# Peter Chelsom   164     -79627709
# Length: 644, dtype: int64

# %%
x=df.year.value_counts(ascending=False)

# %%
x[x>70]
# Out:
# year
# 2006    73
# 2005    71
# Name: count, dtype: int64

# %%
df.iloc[[3]]
# Out:
#     id_x     budget  popularity     revenue                  title  \
# 3  43600  250000000         112  1084939099  The Dark Knight Rises
#
#    vote_average  vote_count  director_id  year month     day  \
# 3           7.6        9106         4765  2012   Jul  Monday
#
#        director_name  id_y gender     release_date decade
# 3  Christopher Nolan  4765   Male  Monday-Jul-2012    10s

# %%
df.iloc[3].isna().sum().sum()
# Out:
# np.int64(0)

# %%
s='How much wood would a woodchuck chuck if a woodchuck could chuck wood'

# %%
pd.Series(s.split()).value_counts()
# Out:
# wood         2
# chuck        2
# a            2
# woodchuck    2
# How          1
# would        1
# much         1
# if           1
# could        1
# Name: count, dtype: int64

# %%
d=pd.to_datetime('3rd Jul')
d
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# conversion.pyx in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# np_datetime.pyx in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: result would overflow
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /tmp/ipython-input-82598164.py in <cell line: 0>()
# ----> 1 d=pd.to_datetime('3rd Jul')
#       2 d
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1099             result = convert_listlike(argc, format)
#    1100     else:
# -> 1101         result = convert_listlike(np.array([arg]), format)[0]
# ...

# %%
str(d.year)+'-'+str(d.month).zfill(2)+'-'+str(d.day).zfill(2)
# Out:
# '1984-03-01'

# %%
from datetime import datetime
d=datetime.strptime('3rd Jul 3532',"%d-%m-%Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3421316751.py in <cell line: 0>()
#       1 from datetime import datetime
# ----> 2 d=datetime.strptime('3rd Jul 3532',"%d-%m-%Y")
#
# /usr/lib/python3.11/_strptime.py in _strptime_datetime(cls, data_string, format)
#     565     """Return a class cls instance based on the input string and the
#     566     format string."""
# --> 567     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     568     tzname, gmtoff = tt[-2:]
#     569     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.11/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# ...

# %%
" ".join('3rd Jul 3532'.split())
# Out:
# '3rd Jul 3532'

# %%
month_map = {
    "Jan": "01", "Feb": "02", "Mar": "03", "Apr": "04",
    "May": "05", "Jun": "06", "Jul": "07", "Aug": "08",
    "Sep": "09", "Oct": "10", "Nov": "11", "Dec": "12"
}

def convert_date(date_str):
    # Split the string into parts
    day_str, month_str, year_str = date_str.split()
    print(day_str)

    # Remove suffix from day (1st, 2nd, 3rd, etc.)
    day = ''.join(filter(str.isdigit, day_str)).zfill(2)
    month = month_map[month_str]
    year = year_str

    return f"{year}-{month}-{day}"

# %%
convert_date('3rd Jul 3532')
# Out:
# '3532-07-03'

# %%
day_str='3rd'

# %%
''.join(filter(str.isdigit, day_str)).zfill(2)
# Out:
# '03'

# %%
filter(str.isdigit, day_str)

# %%
day_str.isdigit()
# Out:
# False

# %%
'3'.zfill(3)
# Out:
# '003'

# %%
# !gdown 1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# To: /content/sales.csv
# 100% 94.9M/94.9M [00:01<00:00, 64.6MB/s]

# %%
df=pd.read_csv('sales.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df['date']=pd.to_datetime(df['InvoiceDate']).dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
#  8   date         1067371 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 73.3+ MB

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country        date
# ...

# %%
x=pd.to_datetime("22nd June 2011")
# Out:
# <bound method Timestamp.date of Timestamp('2011-06-22 00:00:00')>

# %%
df[df['date'].astype('str')=='2011-06-22']['Customer ID'].nunique()
# Out:
# 57

# %%
data.query("title == 'Spider-Man 3'").get('director_name')
# Out:
# 4    Sam Raimi
# Name: director_name, dtype: object

# %%
data['decade'].value_counts()
# Out:
# decade
# 00s    644
# 90s    376
# 10s    293
# 80s    126
# 70s     26
# Name: count, dtype: int64

# %%
x=data[data.decade=='00s']

# %%
x.director_name.value_counts()
# Out:
# director_name
# Clint Eastwood      9
# Robert Rodriguez    9
# Woody Allen         8
# Shawn Levy          7
# Adam Shankman       7
#                    ..
# Kenneth Branagh     1
# Paul Verhoeven      1
# John Carpenter      1
# Sidney Lumet        1
# David Lynch         1
# Name: count, Length: 196, dtype: int64

# %%
x['profit']=x['revenue']-x['budget']
# Out:
# /tmp/ipython-input-1898890639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['profit']=x['revenue']-x['budget']

# %%
x.sort_values(by='profit',ascending=False).head(10)
# Out:
#       id_x     budget  popularity     revenue  \
# 0    43597  237000000         150  2787965087
# 199  43926   94000000         123  1118888979
# 8    43609  200000000         145  1065659812
# 117  43794  125000000         109   976475550
# 200  43927   79000000         106   926287400
# 23   43629  200000000          78  1025491110
# 45   43662  185000000         187  1004558444
# 156  43859   93000000         138   871368364
# 167  43873  100000000         132   876688482
# 328  44162  150000000          47   919838758
#
#                                                  title  vote_average  \
# 0                                               Avatar           7.2
# 199      The Lord of the Rings: The Return of the King           8.1
# 8           Pirates of the Caribbean: Dead Man's Chest           7.0
# 117           Harry Potter and the Philosopher's Stone           7.5
# 200              The Lord of the Rings: The Two Towers           8.0
# ...
