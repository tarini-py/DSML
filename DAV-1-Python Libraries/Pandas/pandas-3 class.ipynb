# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #concatenation

# %%
users = pd.DataFrame({'userid':[1,2,3],'name':['vinayak','mayank','aravind']})
users
# Out:
#    userid     name
# 0       1  vinayak
# 1       2   mayank
# 2       3  aravind

# %%
#doubt
users_1 = pd.DataFrame({'userid':[1,2,np.nan],'name':['vinayak','mayank','aravind']})
users_1
# Out:
#    userid     name
# 0     1.0  vinayak
# 1     2.0   mayank
# 2     NaN  aravind

# %%
#float object in numpy

# %%
msgs = pd.DataFrame({'userid':[1,1,2,4],'msg':['hmm','ohk','haha','thik hai']})
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1       ohk
# 2       2      haha
# 3       4  thik hai

# %%
pd.concat([users,msgs])  #default axis=0
# Out:
#    userid     name       msg
# 0       1  vinayak       NaN
# 1       2   mayank       NaN
# 2       3  aravind       NaN
# 0       1      NaN       hmm
# 1       1      NaN       ohk
# 2       2      NaN      haha
# 3       4      NaN  thik hai

# %%
pd.concat([users,msgs],axis=0)
# Out:
#    userid     name       msg
# 0       1  vinayak       NaN
# 1       2   mayank       NaN
# 2       3  aravind       NaN
# 0       1      NaN       hmm
# 1       1      NaN       ohk
# 2       2      NaN      haha
# 3       4      NaN  thik hai

# %%
pd.concat([users,msgs],axis=1)
# Out:
#    userid     name  userid       msg
# 0     1.0  vinayak       1       hmm
# 1     2.0   mayank       1       ohk
# 2     3.0  aravind       2      haha
# 3     NaN      NaN       4  thik hai

# %%
type(np.nan) #NaN or none  => missing values in the next class ?
# Out:
# float

# %% [markdown]
# #merging (joins)
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/065/710/original/joins.webp?1708409218">

# %%
users
# Out:
#    userid     name
# 0       1  vinayak
# 1       2   mayank
# 2       3  aravind

# %%
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1       ohk
# 2       2      haha
# 3       4  thik hai

# %%
users.merge(msgs) #default join => inner
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha

# %%
users.merge(msgs,on='userid')
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha

# %%
users.merge(msgs,on='userid',how='inner')
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha

# %%
users.merge(msgs,on='userid',how='left')
# Out:
#    userid     name   msg
# 0       1  vinayak   hmm
# 1       1  vinayak   ohk
# 2       2   mayank  haha
# 3       3  aravind   NaN

# %%
users.merge(msgs,on='userid',how='right')
# Out:
#    userid     name       msg
# 0       1  vinayak       hmm
# 1       1  vinayak       ohk
# 2       2   mayank      haha
# 3       4      NaN  thik hai

# %%
users.merge(msgs,on='userid',how='outer') #full outer join
# Out:
#    userid     name       msg
# 0       1  vinayak       hmm
# 1       1  vinayak       ohk
# 2       2   mayank      haha
# 3       3  aravind       NaN
# 4       4      NaN  thik hai

# %%
users
# Out:
#    userid     name
# 0       1  vinayak
# 1       2   mayank
# 2       3  aravind

# %%
users.rename(columns = {'userid':'id'},inplace=True)
users
# Out:
#    id     name
# 0   1  vinayak
# 1   2   mayank
# 2   3  aravind

# %%
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1       ohk
# 2       2      haha
# 3       4  thik hai

# %%
users.merge(msgs,left_on = 'id' ,right_on = 'userid',how='left')
# Out:
#    id     name  userid   msg
# 0   1  vinayak     1.0   hmm
# 1   1  vinayak     1.0   ohk
# 2   2   mayank     2.0  haha
# 3   3  aravind     NaN   NaN

# %% [markdown]
# # IMDB Dataset

# %%
#imdb datasets
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 115MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 67.0MB/s]

# %%
#loading these files using pandas
movies = pd.read_csv('movies.csv',index_col = 0) #index_col = 'id' > try
directors = pd.read_csv('directors.csv',index_col = 0)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies['director_id'].nunique()
# Out:
# 199

# %%
directors['id'].nunique()
# Out:
# 2349

# %%
#how can we check if all director_id from movies present in id of directors
['deep','man'] in ['sandeep','mandeep']
# Out:
# False

# %%
'deep' in 'sandeep'
# Out:
# True

# %%
'deep' in 'mandeep'
# Out:
# True

# %%
#merging movies and directors datasets
#isin
movies['director_id'].isin(directors['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4736    True
# 4743    True
# 4748    True
# 4749    True
# 4768    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.sum(movies['director_id'].isin(directors['id']))
# Out:
# np.int64(1465)

# %%
movies['director_id'].isin(directors['id']).value_counts()
# Out:
# director_id
# True    1465
# Name: count, dtype: int64

# %%
np.all(movies['director_id'].isin(directors['id']))
# Out:
# np.True_

# %%
#pd.merge(movies,directors,how='left',left_on='director_id',right_on='id')

# %%
data = movies.merge(directors,how='left',left_on='director_id',right_on='id')
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.drop(['director_id','id_y'],axis=1,inplace=True)
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %% [markdown]
# #post read => imdbd data exploration
# https://colab.research.google.com/drive/1yrfHSQYUMxxLKGUG-gCPf-R232BuimiR?usp=sharing

# %%
#quiz
# How to filter those records where movies are released either in the year 2015, 2016 or 2012 from the movies dataset?
2026 in([2016,2017,2018,2025])
# Out:
# False

# %%
[2016,2018] in([2016,2017,2018,2025])
# Out:
# False

# %%
data['year'].isin([2016,2015,2012])
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: year, Length: 1465, dtype: bool

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#apply() => apply function along an axis of the df => axis=0

# %%
def encode(data):
  if data=="Male":
    return 0
  else:
    return 1

# %%
data['gender'] = data['gender'].apply(encode)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#apply function to multiple columns

data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['overall-summation'] = data[['revenue','budget']].apply(np.sum,axis=1)
# Out:
# 0       3024965087
# 1       1261000000
# 2       1125674609
# 3       1334939099
# 4       1148871626
#            ...
# 1460        321952
# 1461       3178130
# 1462             0
# 1463             0
# 1464       2260920
# Length: 1465, dtype: int64

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
def prof(x):
  return x['revenue']-x['budget']

# %%
 data[['revenue','budget']]
# Out:
#          revenue     budget
# 0     2787965087  237000000
# 1      961000000  300000000
# 2      880674609  245000000
# 3     1084939099  250000000
# 4      890871626  258000000
# ...          ...        ...
# 1460      321952          0
# 1461     3151130      27000
# 1462           0          0
# 1463           0          0
# 1464     2040920     220000
#
# [1465 rows x 2 columns]

# %%
data['profit'] = data[['revenue','budget']].apply(prof,axis=1)
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# #groupby
#
# <img src="https://learning.oreilly.com/api/v2/epubs/urn:orm:book:9781491912126/files/assets/pyds_03in01.png" height="350" width="700"/>

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['director_name'].nunique()
# Out:
# 199

# %%
data.groupby('director_name')

# %%
data.groupby('director_name').ngroups
# Out:
# 199

# %%
data.groupby('director_name').groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
#extract data of a particular group
data.groupby('director_name').get_group('Christopher Nolan')
# Out:
#        id_x     budget  popularity     revenue                  title  \
# 3     43600  250000000         112  1084939099  The Dark Knight Rises
# 45    43662  185000000         187  1004558444        The Dark Knight
# 58    43692  165000000         724   675120017           Interstellar
# 59    43693  160000000         167   825532764              Inception
# 74    43716  150000000         115   374218673          Batman Begins
# 565   44630   46000000          41   113714830               Insomnia
# 641   44793   40000000          74   109676311           The Prestige
# 1341  47170    9000000          60    39723096                Memento
#
#       vote_average  vote_count  year month        day      director_name  \
# 3              7.6        9106  2012   Jul     Monday  Christopher Nolan
# 45             8.2       12002  2008   Jul  Wednesday  Christopher Nolan
# 58             8.1       10867  2014   Nov  Wednesday  Christopher Nolan
# ...

# %%
#how can we find count of movies by each director
data.groupby('director_name')['title'].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
#min year and max year for every director => multiple aggegrate functions to my group
data.groupby('director_name')['year'].min().max()
# Out:
# 2008

# %%
#min year and max year for every director => multiple aggegrate functions to my group
data.groupby('director_name')['year'].aggregate(['min','max'])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
data.groupby('director_name')['year'].agg(['min','max'])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
#Given a dataframe of employee rating info (emp_id, monthly_rating). How will you calculate the average rating of each employee?
data.groupby('emp_id')['monthly_rating'].mean()

# %%
#finding the details of movies by high budget directors
#high budget directors -> any director with atleast one movie with budget > 100M

# %%
dir_budget = data.groupby('director_name')['budget'].max().reset_index()
dir_budget.head()
# Out:
#                  director_name     budget
# 0                   Adam McKay  100000000
# 1                Adam Shankman   80000000
# 2  Alejandro González Iñárritu  135000000
# 3                  Alex Proyas  140000000
# 4              Alexander Payne   30000000

# %%
#doubts
(dir_budget['budget'] > 100000000) == False
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 194     True
# 195    False
# 196     True
# 197    False
# 198     True
# Name: budget, Length: 199, dtype: bool

# %%
names = dir_budget[dir_budget['budget'] > 100000000]['director_name']

# %%
names
# Out:
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
# 15                Barry Sonnenfeld
#                   ...
# 185                      Tim Story
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data[data['director_name'].isin(names)]
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
def kiran(x):
  #atleast two movies

# %%
data.groupby('director_name').filter(kiran)

# %%
# in single line ? => groupbased filtering
data.groupby('director_name').filter(lambda x : x['budget'].max()> 100000000)
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#negation ~

# %%
import pandas as pd

data = {
    'name': ['Elon', 'Jeff', 'Bill', 'Falguni'],
    'gender': ['M', 'F', 'M', 'F'],
    'income': [53000, 28000, 25000, 44000]
}

df = pd.DataFrame(data)

# %%
df[df['income'] == df['income'].max()]['name']
# Out:
# 0    Elon
# Name: name, dtype: object
