# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# To: /content/mckinsey.csv
# 100% 83.8k/83.8k [00:00<00:00, 102MB/s]

# %%
df = pd.read_csv('mckinsey.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df[0] #indexing
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-7-411988699.py in <cell line: 0>()
# ----> 1 df[0] #indexing
#
# ...

# %%
df[0:4] #slicing
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
new_indexing = np.arange(10,1714)

# %%
df.index = new_indexing
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#.loc => explicit indexing , end is also inclusive
#.iloc => implicit indexing, end is not inclusive

# %%
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-12-3260552322.py in <cell line: 0>()
# ----> 1 df.loc[1]
#
# ...

# %%
df.iloc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# Name: 11, dtype: object

# %%
df.loc[10]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 10, dtype: object

# %%
df.head()
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[10:13]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138

# %%
df.head(20)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801   779.445314
# 11  Afghanistan  1957     9240934      Asia    30.332   820.853030
# 12  Afghanistan  1962    10267083      Asia    31.997   853.100710
# 13  Afghanistan  1967    11537966      Asia    34.020   836.197138
# 14  Afghanistan  1972    13079460      Asia    36.088   739.981106
# 15  Afghanistan  1977    14880372      Asia    38.438   786.113360
# 16  Afghanistan  1982    12881816      Asia    39.854   978.011439
# 17  Afghanistan  1987    13867957      Asia    40.822   852.395945
# 18  Afghanistan  1992    16317921      Asia    41.674   649.341395
# 19  Afghanistan  1997    22227415      Asia    41.763   635.341351
# 20  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 21  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 22      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.iloc[10:13]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 20  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 21  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 22      Albania  1952     1282697    Europe    55.230  1601.056136

# %%
df.iloc[-1]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1713, dtype: object

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-20-1145300078.py in <cell line: 0>()
# ----> 1 df.loc[-1]
#
# ...

# %%
#can i pass multiple indexes a the same time
df.iloc[[0,3,1,1]]
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 13  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 11  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#explicit indexing?
temp = df.set_index('country')
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.columns
# Out:
# Index(['year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
#data only about afghanistan
temp.loc['Afghanistan']
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
temp.iloc[3]
# Out:
# year                1967
# population      11537966
# continent           Asia
# life_exp           34.02
# gdp_cap       836.197138
# Name: Afghanistan, dtype: object

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index()
# Out:
#       index      country  year  population continent  life_exp     gdp_cap
# 0        10  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1        11  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2        12  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3        13  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4        14  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1699   1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 7 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 10    Afghanistan  1952     8425333      Asia    28.801  779.445314
# 11    Afghanistan  1957     9240934      Asia    30.332  820.853030
# 12    Afghanistan  1962    10267083      Asia    31.997  853.100710
# 13    Afghanistan  1967    11537966      Asia    34.020  836.197138
# 14    Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1709     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1710     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1711     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1712     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1713     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index?

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#add new rows in your data

# %%
len(df)
# Out:
# 1704

# %%
df.loc[len(df)] = ['India',2025,140,'Asia',50,700]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
#
# [1705 rows x 6 columns]

# %%
df.loc[1705]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1705
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-43-4105940171.py in <cell line: 0>()
# ----> 1 df.loc[1705]
#
# ...

# %%
df.loc[1705] = ['India',2025,140,'Asia',50,700]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
# 1705        India  2025         140      Asia    50.000  700.000000
#
# [1706 rows x 6 columns]

# %%
len(df)
# Out:
# 1706

# %%
df.iloc[len(df)] =  ['India',2025,140,'Asia',50,700]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-46-3373414525.py in <cell line: 0>()
# ----> 1 df.iloc[len(df)] =  ['India',2025,140,'Asia',50,700]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     906             key = self._check_deprecated_callable_usage(key, maybe_callable)
#     907         indexer = self._get_setitem_indexer(key)
# --> 908         self._has_valid_setitem_indexer(key)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1644             elif is_integer(i):
#    1645                 if i >= len(ax):
# -> 1646                     raise IndexError("iloc cannot enlarge its target object")
#    1647             elif isinstance(i, dict):
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
# 1705        India  2025         140      Asia    50.000  700.000000
#
# [1706 rows x 6 columns]

# %%
df.iloc[1705] = ['India',2025,142,'Asia',50,700] #update the row
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
# 1705        India  2025         142      Asia    50.000  700.000000
#
# [1706 rows x 6 columns]

# %%
#can we add duplicate rows in my data
df.loc[len(df)] = ['India',2025,142,'Asia',50,700]
df.loc[len(df)] = ['India',2025,142,'Asia',50,700]
df.loc[len(df)] = ['India',2025,142,'Asia',50,700]
df.loc[len(df)] = ['India',2025,142,'Asia',50,700]
df.loc[len(df)] = ['India',2025,142,'Asia',50,700]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1706        India  2025         142      Asia    50.000  700.000000
# 1707        India  2025         142      Asia    50.000  700.000000
# 1708        India  2025         142      Asia    50.000  700.000000
# 1709        India  2025         142      Asia    50.000  700.000000
# 1710        India  2025         142      Asia    50.000  700.000000
#
# [1711 rows x 6 columns]

# %%
#drop these duplicates
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1706        India  2025         142      Asia    50.000  700.000000
# 1707        India  2025         142      Asia    50.000  700.000000
# 1708        India  2025         142      Asia    50.000  700.000000
# 1709        India  2025         142      Asia    50.000  700.000000
# 1710        India  2025         142      Asia    50.000  700.000000
#
# [1711 rows x 6 columns]

# %%
df.drop([1704,1705,1706,1707,1708,1709,1710])
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1706        India  2025         142      Asia    50.000  700.000000
# 1707        India  2025         142      Asia    50.000  700.000000
# 1708        India  2025         142      Asia    50.000  700.000000
# 1709        India  2025         142      Asia    50.000  700.000000
# 1710        India  2025         142      Asia    50.000  700.000000
#
# [1711 rows x 6 columns]

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2025         140      Asia    50.000  700.000000
# 1705     India  2025         142      Asia    50.000  700.000000
# 1706     India  2025         142      Asia    50.000  700.000000
# 1707     India  2025         142      Asia    50.000  700.000000
# 1708     India  2025         142      Asia    50.000  700.000000
# 1709     India  2025         142      Asia    50.000  700.000000
# 1710     India  2025         142      Asia    50.000  700.000000

# %%
#finding the duplicates
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1706     True
# 1707     True
# 1708     True
# 1709     True
# 1710     True
# Length: 1711, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1706   India  2025         142      Asia      50.0    700.0
# 1707   India  2025         142      Asia      50.0    700.0
# 1708   India  2025         142      Asia      50.0    700.0
# 1709   India  2025         142      Asia      50.0    700.0
# 1710   India  2025         142      Asia      50.0    700.0

# %%
#drop them => inbuild function => searching as well as deleting
df.drop_duplicates

# %%
help(df.drop_duplicates)
# Out:
# Help on method drop_duplicates in module pandas.core.frame:
#
# drop_duplicates(subset: 'Hashable | Sequence[Hashable] | None' = None, *, keep: 'DropKeep' = 'first', inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Return DataFrame with duplicate rows removed.
#
#     Considering certain columns is optional. Indexes, including time indexes
#     are ignored.
#
#     Parameters
#     ----------
#     subset : column label or sequence of labels, optional
#         Only consider certain columns for identifying duplicates, by
#         default use all of the columns.
#     keep : {'first', 'last', ``False``}, default 'first'
#         Determines which duplicates (if any) to keep.
#
#         - 'first' : Drop duplicates except for the first occurrence.
#         - 'last' : Drop duplicates except for the last occurrence.
#         - ``False`` : Drop all duplicates.
#
#     inplace : bool, default ``False``
# ...

# %%
df.tail(15)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704     India  2025         140      Asia    50.000  700.000000
# 1705     India  2025         142      Asia    50.000  700.000000
# 1706     India  2025         142      Asia    50.000  700.000000
# 1707     India  2025         142      Asia    50.000  700.000000
# 1708     India  2025         142      Asia    50.000  700.000000
# ...

# %%
df.drop_duplicates(keep= 'first')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
# 1705        India  2025         142      Asia    50.000  700.000000
#
# [1706 rows x 6 columns]

# %%
df.drop_duplicates(keep= 'last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
# 1710        India  2025         142      Asia    50.000  700.000000
#
# [1706 rows x 6 columns]

# %%
df.drop_duplicates(keep= False)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
#
# [1705 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1706        India  2025         142      Asia    50.000  700.000000
# 1707        India  2025         142      Asia    50.000  700.000000
# 1708        India  2025         142      Asia    50.000  700.000000
# 1709        India  2025         142      Asia    50.000  700.000000
# 1710        India  2025         142      Asia    50.000  700.000000
#
# [1711 rows x 6 columns]

# %%
df.drop_duplicates(keep= False,inplace=True)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2025         140      Asia    50.000  700.000000
#
# [1705 rows x 6 columns]

# %%
#quiz
import pandas as pd

data = {'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
        'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
        'C': ['small', 'large', 'large', 'small', 'small', 'large', 'large', 'small'],
        'D': [1, 2, 2, 3, 3, 4, 5, 6]}

df = pd.DataFrame(data)

# print(sum(df.duplicated(subset=['A', 'B'])))

# %%
# df[['A','B']].duplicated

# %%
df.duplicated(subset=['A', 'B'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
df
# Out:
#      A      B      C  D
# 0  foo    one  small  1
# 1  bar    one  large  2
# 2  foo    two  large  2
# 3  bar  three  small  3
# 4  foo    two  small  3
# 5  bar    two  large  4
# 6  foo    one  large  5
# 7  foo  three  small  6

# %%
df
# Out:
#      A      B      C  D
# 0  foo    one  small  1
# 1  bar    one  large  2
# 2  foo    two  large  2
# 3  bar  three  small  3
# 4  foo    two  small  3
# 5  bar    two  large  4
# 6  foo    one  large  5
# 7  foo  three  small  6

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#slicing on the df

# %%
df.loc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# Name: 1, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[0:4,1:3] #rows and columns together
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-82-661357504.py in <cell line: 0>()
# ----> 1 df.loc[0:4,1:3] #rows and columns together
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1375             return self._multi_take(tup)
#    1376
# -> 1377         return self._getitem_tuple_same_dim(tup)
#    1378
#    1379     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
df.iloc[0:4,1:3] #rows and columns together
# Out:
#    year  population
# 0  1952     8425333
# 1  1957     9240934
# 2  1962    10267083
# 3  1967    11537966

# %%
df.loc[0:4,'year':'population']
# Out:
#    year  population
# 0  1952     8425333
# 1  1957     9240934
# 2  1962    10267083
# 3  1967    11537966
# 4  1972    13079460

# %%
df.loc[0:4,['year','population']]
# Out:
#    year  population
# 0  1952     8425333
# 1  1957     9240934
# 2  1962    10267083
# 3  1967    11537966
# 4  1972    13079460

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[0:4,'year':'continent']
# Out:
#    year  population continent
# 0  1952     8425333      Asia
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1967    11537966      Asia
# 4  1972    13079460      Asia

# %%
df.loc[0:4,['year','continent']]
# Out:
#    year continent
# 0  1952      Asia
# 1  1957      Asia
# 2  1962      Asia
# 3  1967      Asia
# 4  1972      Asia

# %%
df.iloc[0:4,['year','continent']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-90-4081734633.py in <cell line: 0>()
# ----> 1 df.iloc[0:4,['year','continent']]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[0:4:2,1:4]
# Out:
#    year  population continent
# 0  1952     8425333      Asia
# 2  1962    10267083      Asia

# %%
df.iloc[0:4:2,[1,3]]
# Out:
#    year continent
# 0  1952      Asia
# 2  1962      Asia

# %%
#homework
df.loc[0:4,'year':'continent':2]

# %%
#pandas inbuild functions

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
le = df['life_exp']
le
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
#avg /mean life_exp
print(le.mean())
# Out:
# 59.474439366197174

# %%
print(le.min())
# Out:
# 23.599

# %%
print(le.max())
# Out:
# 82.603

# %%
df['life_exp'].mean()
# Out:
# np.float64(59.474439366197174)

# %%
np.mean(le)
# Out:
# np.float64(59.474439366197174)

# %%
#sorting ?
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values?

# %%
temp = df.sort_values(by = 'life_exp')
temp
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
temp = df.sort_values(by = 'life_exp',ascending=False)
temp
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by = ['year','life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 71           Australia  2007    20434176   Oceania    81.235  34435.367440
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(by = ['year','life_exp'],ascending=False)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 71           Australia  2007    20434176   Oceania    81.235  34435.367440
# ...                ...   ...         ...       ...       ...           ...
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
#
# [1704 rows x 6 columns]

# %%
temp = df.sort_values(by = ['year','life_exp'],ascending=[False,True])

# %%
temp
# Out:
#            country  year  population continent  life_exp       gdp_cap
# 1463     Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1043    Mozambique  2007    19951656    Africa    42.082    823.685621
# 1691        Zambia  2007    11746035    Africa    42.384   1271.211593
# 1355  Sierra Leone  2007     6144562    Africa    42.568    862.540756
# 887        Lesotho  2007     2012649    Africa    42.592   1569.331442
# ...            ...   ...         ...       ...       ...           ...
# 408        Denmark  1952     4334000    Europe    70.780   9692.385245
# 1464        Sweden  1952     7124673    Europe    71.860   8527.844662
# 1080   Netherlands  1952    10381988    Europe    72.130   8941.571858
# 684        Iceland  1952      147962    Europe    72.490   7267.688428
# 1140        Norway  1952     3327728    Europe    72.670  10095.421720
#
# [1704 rows x 6 columns]

# %%
temp.reset_index(drop=True,inplace=True)

# %%
temp
# Out:
#            country  year  population continent  life_exp       gdp_cap
# 0        Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1       Mozambique  2007    19951656    Africa    42.082    823.685621
# 2           Zambia  2007    11746035    Africa    42.384   1271.211593
# 3     Sierra Leone  2007     6144562    Africa    42.568    862.540756
# 4          Lesotho  2007     2012649    Africa    42.592   1569.331442
# ...            ...   ...         ...       ...       ...           ...
# 1699       Denmark  1952     4334000    Europe    70.780   9692.385245
# 1700        Sweden  1952     7124673    Europe    71.860   8527.844662
# 1701   Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1702       Iceland  1952      147962    Europe    72.490   7267.688428
# 1703        Norway  1952     3327728    Europe    72.670  10095.421720
#
# [1704 rows x 6 columns]

# %%
df.to_csv('final.csv', index=True)

# %% [markdown]
# #concatenation

# %%
users = pd.DataFrame({
    'userid':[1,2,3],
    'name':['raj','eniyan','komal']
})
users
# Out:
#    userid    name
# 0       1     raj
# 1       2  eniyan
# 2       3   komal

# %%
msgs = pd.DataFrame({
    'userid':[1,1,2,4],
    'msg':['hmm','ok','haha','thik hai']
})
msgs
# Out:
#    userid       msg
# 0       1       hmm
# 1       1        ok
# 2       2      haha
# 3       4  thik hai

# %%
pd.concat([users,msgs])
# Out:
#    userid    name       msg
# 0       1     raj       NaN
# 1       2  eniyan       NaN
# 2       3   komal       NaN
# 0       1     NaN       hmm
# 1       1     NaN        ok
# 2       2     NaN      haha
# 3       4     NaN  thik hai
