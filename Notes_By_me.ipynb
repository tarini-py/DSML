# %% [markdown]
# <a href="https://colab.research.google.com/github/tarini-py/Data-Science-Machine-Learning-DSML/blob/main/Notes_By_me.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probability**
#
#
# ---
#
#
#
# ---
# #Events
# 1. Mutually Exclusive or Disjoint : A ∩ B = {}
# 2. Exhaustive Event : union of all Events is Sample set
# 3. If Both 1 & 2 Hold then Partition of Sample space
# 4. Non Mutually Exclusive Events (Joint Events) : A ∩ B is not {}
# 5. Independent Events :
#    <br>**$P(A∩B) = P(A) * P(B)$**<br>
#    if A & B are independent
#    So, if the Events are Independent they cannot be Mutually Exclusive or Disjoint and vice a versa
#
# <br>
# Pobability formula = $\Large\frac{Possible \ oucomes}{Total \ outcomes}$
#
# <br>
#
# Addition rule : **$P(A∪B) = P(A) + P(B) - P(A∩B)$**
#
# <br>
#
# In case of **Disjoint Events**
#
#   - the intersection of $A ∩B = \{ \ \}$ so, $P(A∩B) = 0$
#
#     - therefore, **$P(A∪B) = P(A) + P(B)$**

# %% [markdown]
# #Conditional probability & Bayes Theorem
#
#
# ---
#
#
#
# ---
# Conditional Probability: <br>
# formula: <br>
# - $P(A|B) = \frac{P(A∩B)}{P(B)}$
#
# Probability of A given that B has already happened.
#
# Multiplication Rule:<br>
#  - $P(A∩B) = P(A|B).P(B)$<br>
#  - $P(B∩A) = P(B|A).P(A)$<br>
#
#
#
# Marginal Probability:
# - Probability of Single event without considering other events. i.e $P(A)$
#
# Joint Probability:
# - Probability of Two or more events together. It is represented as $P(A ∩ B)$.
#
# Law of Total Probability:
#
# - $P(A) = \sum_{i=1}^n P(A \mid B_i)  P(B_i)$
#
# Baye's Theorem
#
# - $P(A|B) = \frac{P(B|A).P(A)}{P(B)}$

# %% [markdown]
# Let's take a closer look at the Bayes equation.
#
# ### <font color='blue'>**Prior, Posterior and Likelihood Probabilities**</font>
#
# It consists of 4 parts:
# - **Posterior probability** (updated probability after the evidence is considered)
# - **Prior probability** (the probability before the evidence is considered)
# - **Likelihood** (probability of the evidence, given the belief is true)
# - **Marginal probability** (probability of the evidence, under any circumstance)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To understand this better, let's think in a different context.
#
# Consider 2 events:
# - **Hypothesis** (which can be true or false), and
# - **Evidence** (which can be present or absent).
#
# Therefore, we can write bayes theorem as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's understand the different terms here.
# -  **Posterior probability**
#  - The Bayes' Theorem lets you calculate the posterior (or "updated") probability.
#  - It is the conditional probability of the **hypothesis being true, if the evidence is present.**
#  - $P(Hypothesis | Evidence)$
#
# - **Prior Probability**
#  - Can be perceived as your **belief in the hypothesis before seeing the new evidence.**
#  - Therefore, if we have a strong belief in the hypothesis already, the prior probability will be large.
#  - $P(Hypothesis)$
#
# - **Likelihood**
#  - The prior is multiplied by a fraction.
#  - Think of this as the "strength" of the evidence.
#
#  - The posterior probability is greater when the top part (numerator) is big, and the bottom part (denominator) is small.
#
#  - The numerator is the likelihood.
#  - It is the conditional probability of the **evidence being present, given the hypothesis is true.**
#
#  - This is not the same as the posterior!! $P(Evidence | Hypothesis) \neq P(Hypothesis  |Evidence)$
#
# - **Marginal Probability**
#  - Notice the denominator of this fraction.
#  - It is the marginal probability of the evidence. $P(Evidence)$
#  - That is, it is the **probability of the evidence being present, whether the hypothesis is true or false.**
#  - We can find it using Total Probability Law
#  - The smaller the denominator, the more "convincing" the evidence
#
# <br>
# <br>
# <br><br>
#
# <br>
# <br>
# <br>

# %% [markdown]
# #Probability Dstribution
#
#
# ---
#
#
# - PDF : Continous Random variable(floating point number)
# - PMF : Discrete Random Variable(whole number)
# - CDF : For both RV,probability less than or equal to a specified   value
#
#
#
# ---
#
# - `Expectation of a random variable X, is the weighted average of the values that X takes, with the weights being the probabilities.`
# - Expected Value = mean
# - $E(X) = Σ_i X_i*P(X = X_i)$
#
# where
# - $X$ was our random variable that denotes the no of red balls drawn.
# - $P(X = X_i)$ represents the probability of X getting a value of $X_i$
# - $E(X)$ is known as the **Expected value** of the random variable $X$
#
# <br>
#
# #Binomial Distribution(n trials)
#
# - For Discrete RV only
# - always have two possible outcome
#   -  Success / Win
#   -  Failure / Loss
# - $P(X = k) = \ ^nC_k \ (p)^k \ (1-p)^{n-k}$
#
# - `scipy.stats.binom.pmf(n,p,k)`
# - `scipy.stats.binom.expect(args=(n,p))`
# - Variance $\Large( σ^2 )= n * p * (1-p)$
# - Standard Deviation : $\Large σ $
# - E(x) = Mean = n*p
#
# #Bernouli Trials( 1 trial)
#
# - Binomial is repeted Bernouli Trials
# - Bernouli Trial is single experiment
#   - Only two outcomes
#     - Success(p) or  P(X=1) = p
#     - Failure(1-p) or P(X=0) = 1-p
#
# - E(x) = Mean = 0.(1-p) + 1.(p)
# - Variance = p(1-p)
#
#
#
# ---
# #Uniform Distribution
#
# - For both Discrete and Continous RV
#
# PMF(x) = P(X = x) = 1 / (b - a + 1) for a ≤ x ≤ b
#
# PMF(x) = P(X = x) = 0 otherwise
#
# <br>
#
# PDF(x) = 1 / (b - a) for a ≤ x ≤ b
#
# PDF(x) = 0 otherwise
#
# <br>
#
# **$P(x_1 < X < x_2) = \Large \frac{(x_2 – x_1)}{(b – a)}$**
#
# <br>
# The uniform distribution has the following properties:
#
# - Mean: $\Large \frac{(a + b)}{2}$
#
#
# - Variance: $\Large \frac{(b – a)^2}{12}$, for Continuous uniform distributions
#
# - Variance: $\Large \frac{(b – a+1)^2 -1}{12}$, for Discrete uniform distributions
#
# - Standard Deviation: $\Large \sqrt\frac {(b – a)^2}{12}$, for Continuous uniform distributions.
#
# - Standard Deviation: $\Large \sqrt\frac{(b – a+1)^2 -1}{12}$, for Discrete uniform distributions.
#
#
#
# ---
# #Normal Distribution
#
# $z = \frac{{x - \mu}}{{\sigma}}$
#
# `norm.cdf(z-score)` gives %
#
# `norm.ppf(percentile)` gives z-score
#
#
# ## <font color='blue'>**Standard Normal Distribution**</font>
#
# The special case, when a normal distribution has
# - $μ = 0$, and
# - σ$= 1$
#
# It is known as The **Standard Normal Distribution**, also called the **z-distribution**
# - And, it is denoted by $Z(0,1)$
#
# <br>
#
# We can take <font color='purple'>any Normal Distribution and convert it to The Standard Normal Distribution, using **Standardization**</font>
#
#
# <br>
#
# ---
#
#
#
# ---
#
# #CLT & CI
#
# $\Large Z = \frac{\bar X - \mu}{\frac{\sigma}{\sqrt n}}$
# Where,
# - $\bar X$ = sample mean
# - $\mu$ - population mean
# - $\sigma/\sqrt n$ = standard error
#
# `norm.interval(confidence_%, loc=mean, scale=std_error)`
#
#
# Confidence Interval = $\Large \bar X ± Z \left( \frac {σ}{\sqrt n}\right)$
#
# OR
# $\Large [\bar {X} - Z * (\frac{σ}{\sqrt n}) \ ,\  \bar {X} + Z * (\frac{σ}{\sqrt n})]$
#
# where:
#
# $\bar X$: sample mean
#
# $z$: is the z-score corresponding to the desired confidence level.
#
# $σ/ \sqrt n$: standard error

# %% [markdown]
# ### **Poisson Distribution Formula**
# If a random variable $X$ follows a Poisson distribution, then the probability that $X = k$ successes can be found by the following formula:
#
# - **$P[X=k] = \Large \frac{λ^k \ * \  e^{-λ}}{k!}$**
#
#   where:
#
#   - **λ**: rate or mean number of successes that occur during a specific interval
#
#   - **k**: number of successes
#
#   - **e**: a constant equal to approximately 2.71828
#
# This is also known as **Probability Mass Function (PMF)** of poisson distribution as using this formula we can calculate the probability of exact events.
#
# - `poisson.pmf(k=0,mu=rate per time)`
#
# - if n>= 20 & p<=0.05 then poission aproximate binom
#
# #Exponetial Dist
#
# `expon.cdf(x=,scale=)`
#
# scale=1/rate
#
# #Geometric Dist
# - Mean $(μ)$ = $\Large \frac{1}{Probability \ of \ Success}$
#
# - Or, **$E[X] = 1/p$**
#
# - probability that we have to throw 4 times is
#
# - k = no. of trials and p = success rate
# - prob = `geom.pmf(k=4, p=1/6)`

# %% [markdown]
# ![Screenshot 2025-09-16 203008.png](data:image/png;base64,...)
